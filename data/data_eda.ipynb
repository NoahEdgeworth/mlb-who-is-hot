# %%
from data_fetch import get_monthly_batting_stats, get_monthly_pitching_stats
import pandas as pd

# %%
batting_df = get_monthly_batting_stats()
batting_df.head(50)
# Out:
#                        Name  Age  #days     Lev  ...    OBP    SLG    OPS   mlbID
# 1                 CJ Abrams   24      0  Maj-NL  ...  0.268  0.364  0.631  682928
# 2              Wilyer Abreu   26      0  Maj-AL  ...  0.300  0.500  0.800  677800
# 3    Luisangel Acu\xc3\xb1a   23      0  Maj-NL  ...  0.286  0.308  0.593  682668
# 4   Ronald Acu\xc3\xb1a Jr.   27      1  Maj-NL  ...  0.348  0.542  0.890  660670
# 5              Willy Adames   29      0  Maj-NL  ...  0.408  0.697  1.105  642715
# 6               Riley Adams   29      0  Maj-NL  ...  0.313  0.405  0.717  656180
# 7                  Jo Adell   26      0  Maj-AL  ...  0.284  0.411  0.695  666176
# 8              Ozzie Albies   28      0  Maj-NL  ...  0.284  0.364  0.647  645277
# 9   Sergio Alc\xc3\xa1ntara   28     19  Maj-NL  ...  0.000  0.000  0.000  642727
# 10          Blaze Alexander   26      0  Maj-NL  ...  0.333  0.350  0.683  677942
# ...

# %%
pitching_df = get_monthly_pitching_stats()
pitching_df
# Out:
#                Name  Age  #days     Lev  ...  BAbip   SO9   SO/W   mlbID
# 1     Andrew Abbott   26      3  Maj-NL  ...  0.357   6.4   4.00  671096
# 2         Mick Abel   23     21  Maj-NL  ...  0.500  16.2   0.60  690953
# 3       Bryan Abreu   28      1  Maj-AL  ...  0.333  18.9  14.00  650556
# 4        Jason Adam   33      2  Maj-NL  ...  0.375   4.1   0.75  592094
# 5      Travis Adams   25      5  Maj-AL  ...  0.344   6.0   6.00  701519
# ..              ...  ...    ...     ...  ...    ...   ...    ...     ...
# 514     Kirby Yates   38      0  Maj-NL  ...  0.182   9.0   1.25  489446
# 515      Craig Yoho   25     21  Maj-NL  ...  0.333   6.8   1.00  684974
# 516   Brandon Young   26      1  Maj-AL  ...  0.340   8.5   3.40  687064
# 517  Ryan Zeferjahn   27      1  Maj-AL  ...  0.308  12.6   1.17  666171
# 518     Angel Zerpa   25      5  Maj-AL  ...  0.111  11.1   1.75  672582
#
# [499 rows x 41 columns]

# %%
def fix_double_escaped(x):
    try:
        # Decode the literal escape sequences first
        # Then decode as UTF-8 bytes
        return bytes(x, "utf-8").decode("unicode_escape").encode("latin1").decode("utf-8")
    except Exception:
        return x

# %%
batting_df['Name'] = batting_df['Name'].apply(fix_double_escaped)

# %% [markdown]
# Main Stats to track for hitting

# %%
hr_leaders = batting_df.sort_values(by='HR', ascending=False)
hr_leaders
# Out:
#                 Name  Age  #days     Lev  ...    OBP    SLG    OPS   mlbID
# 391   Eugenio Suárez   33      0  Maj-NL  ...  0.325  0.696  1.021  553993
# 357   Kyle Schwarber   32      0  Maj-NL  ...  0.338  0.706  1.044  656941
# 308   Salvador Perez   35      0  Maj-AL  ...  0.411  0.853  1.264  521692
# 388     Kyle Stowers   27      0  Maj-NL  ...  0.443  0.867  1.310  669065
# 22   Randy Arozarena   30      0  Maj-AL  ...  0.329  0.662  0.991  668227
# ..               ...  ...    ...     ...  ...    ...    ...    ...     ...
# 140       Zack Gelof   25     11  Maj-AL  ...  0.143  0.080  0.223  680869
# 138    Maikel Garcia   25      0  Maj-AL  ...  0.247  0.265  0.511  672580
# 326     Luis Rengifo   28      0  Maj-AL  ...  0.312  0.338  0.650  650859
# 327   Bryan Reynolds   30      0  Maj-NL  ...  0.224  0.288  0.512  668804
# 468      Jared Young   29     10  Maj-NL  ...  0.000    NaN    NaN  676724
#
# [451 rows x 28 columns]

# %%
ba_leaders = batting_df.sort_values(by='BA', ascending=False)

# %%
obp_leaders = batting_df.sort_values(by='OBP', ascending=False)

# %%
ops_leaders = batting_df.sort_values(by='OPS', ascending=False)

# %%
rbi_leaders = batting_df.sort_values(by='RBI', ascending=False)
